# %% [markdown]
# <a href="https://colab.research.google.com/github/dredelander/pandas_cheat_sheet/blob/main/FUC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###### FREQUENTLY USED CODE ######

# %%
### Format Print ####

print('Contribution for gross pay: $',format(contrib, ',.2f'),sep='')

# %%
### FUNCTIONS #####

# Function for a new column based on values from another one

def demand_window(row):
    if 17 <= row['DOW Factor'] <= 22:
        return 20
    elif 82 <= row['DOW Factor'] <= 396:
        return 15
    elif 1 <= row['DOW Factor'] <=16:
        return 25
    else:
        return 35

df['Demand Order Window'] = df.apply(demand_window, axis =1)

# Percentage Change (Double Index):
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()

# split Columns on character Lambda function
df['Reason'] = df['title'].apply(lambda title: title.split(':')[0])

# Extract attributes from a datestime type:
df['Month'] = df['timeStamp'].apply(lambda time: time.month)

# How to map values:
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['Day of Week'] = df['Day of Week'].map(dmap)

# Function to sum the number of values that include a string
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))

# %%
### DATA CLEAN UP AND MANIPULATION


# Make a number a float
items['Last Purchase Price'] = items['Last Purchase Price'].str.replace(',',"").astype(float)

# Drop Columns:
df = df.drop(columns=['On Hand','Demand Allocations','Net Flow','R+ Lead Time','Bottleneck Transaction', 'Internal ID'])

# Change to String:
df['Supply Order to Expedite'] = df['Supply Order to Expedite'].astype('str')

# Format Date Column to pd.datetime

df1['Date'] = pd.to_datetime(df1['Date'], format='%m/%d/%Y')

#Groupby and keep values based on the min of another column:

df2 = df1.iloc[df1.groupby(['Line Item Name'])['Due in Number of Days'].idxmin()]

# Returning/Saving different excel/files based on row values:

gp = df_f.groupby('Vendor_y')
gp.apply(lambda x: x.to_excel('Alert '+ str(x.name) + '.xlsx'))

# Rename a column:
costint.rename(columns={'NAME':'Name'}, inplace=True)

#Group by method that keeps selected columns with an operator:
f = {'Quantity': 'sum', 'Qty Open': 'sum', 'Vendor': 'first', 'Due Date': 'first', 'PO #':'first'}

ordersum = ordersum.groupby(['Line Item Name'], as_index=False).agg(f)

# Filtering a dataframe based on starting values of a cell in a column:
Pumps = df[df['Item'].str.match('DWP') |df['Item'].str.match('SPU') |df['Item'].str.match('OBA')]

# Sort a df based on column values:
pumpfam = pumpfam.sort_values('Amount', ascending = False)

# Group by date parameters (month here) and another column with an operator:
pumpmonthly = Pumps.groupby(Pumps['Date'].dt.strftime('%B'))['Amount'].sum().sort_values()

# Insert an index to a series, and make a new column with header:
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
pumpmonthly = pumpmonthly.reindex(new_order, axis=0)
pumpmonthly = pd.DataFrame(pumpmonthly,)
pumpmonthly.reset_index(inplace = True)
pumpmonthly.columns = ['Month','Amount']

# Remove the last row from the dataframe:
usage1 = usage1[:-1]

# Histogram of a column in a df:
someusage['USAGE 12 MO'].plot.hist()

# Drop a column:
highusage = someusage.drop('ON HAND', axis =1)

# Drop duplicates:
df.drop_duplicates(subset=['Document Number/ID'], keep='first', inplace = True)

# Frequency table from a df:
freq = pd.DataFrame(hist.Item.value_counts().reset_index().values, columns=["Item", "Frequency"])
freqindex = freq.sort_index(axis = 0, ascending=True)
freqindex

# Add a bin column based on equally separated bins:
df['likes_cat_equal_size'] = pd.qcut(df['likes'], q = 5 , labels= [1, 2, 3, 4, 5])

# Add bins based on values
df['Cost Category'] = pd.cut(df['Last Purchase Price'], 
                             bins = [-np.inf, 10, 50, 100, 150,250,500,1000, np.inf], labels= [1, 2, 3, 4, 0.217, 0.218,0.219,0.2195])
# Skip a row when reading a file:
df = pd.read_excel('cars prestige survey.xlsx', skiprows = 1)

#Crosstab
pd.crosstab(UnitSalePrice_cat, ProductLine, margins = True, normalize = True)*100

# Indexin by values:
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()] #['EmployeeName']
or
sal.loc[sal['TotalPayBenefits'].idxmax()]

# How to make a Pivot table
pivot = pd.pivot_table(df, index='Item', columns='Month', values='Quantity', aggfunc=sum, fill_value=0)

# Select an items/index from a pivot table && PERCENTAGE CHANGE:
pivot[(pivot.index == "040-39133")].pct_change(periods=4, axis=1)

## Strip a character from a column series:
data['Variance'] = data['Variance'].str.rstrip('%')

# %%
### PLOTS ###

# Count Plot
sns.countplot(x='cut',data=diamonds)

#Purple Heatmat for null values:
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# Box Plot
sns.boxplot(x='cut',y='price',data=diamonds)

# Correlation bar plot:
df.corr()['perot'][:-1].sort_values().plot(kind='bar')

# Pie chart with percentages:
df.groupby('Order method type')['Planned revenue'].sum().plot(kind = 'pie', autopct = '%1.1f%%')

# SNS Correclation Heatmap:
plt.figure(figsize = (15,6))
plt.title = 'Model 1 Correlation'

ax = sns.heatmap(df1.corr(),cmap='coolwarm', annot=True,linewidths=1.5)

# Distribution plot:
sns.distplot(y_test-predictions, bins =50)

# Joint plot sns:
sns.jointplot(x= y_test, y = predictions, kind = 'scatter')
